# %% [markdown]
# # Information we have gotten about the different courses so far

# %% [markdown]
# - __Opposite of what we expected, the Date of Issue does not always correspond with the homoglation number listed on the website :')__
# <br> <br>
# Example: "NOR_Bodo_20_51-05_2-5.png" where the original registration number for the certificate was 15/04.05/2,5. We can see that the Date of Issue was in 2015, but this doesn't show in the name of the certificate-file

# %% [markdown]
# ![Skjermbilde%202021-12-29%20kl.%2019.38.46.png](attachment:Skjermbilde%202021-12-29%20kl.%2019.38.46.png)

# %% [markdown]
# We can double-check that the certificate was not crawled with the wrong homoglation number in the filename by checking with the link available on the FIS homepage: https://medias3.fis-ski.com/pdf/homologations/CC/NOR/NOR_Bodo_20_51-05_2-5.pdf
# <br> Also in this link can we see that the filename in the path is the same as the saved filename for the certificate
# ***

# %% [markdown]
# - __File size does not disclose whether the certificate is a scanned document or a digital copy__

# %% [markdown]
# We can see this by manually comparing the different pdfs. While some the small sized images with a size *>=633kB* were in fact scanned documents, I also found scanned files with a size of *2,1MB*, making them the biggest files in the folder. Seeing that we at this point seem to be missing some image files in "NOR-pdfs/", I will not assume that 633kb is a border that remains true for the so far unseen certificates.
# <br> The digital (and searchable) certificates also differed, within the range *1,5MB-633kB*
# ***

# %% [markdown]
# - __The Cisdem PDF Converter OCR software worked as hoped, but must be looked over__

# %% [markdown]
# Ran program on all found pdfs in "NOR-pdfs/"-folder, even those that were digital copies (and therefore already searchable) from before. <br>
# When comparing one of these searchable certificates' before-and-after, the original version seemed to be in minimally better shape for data extraction, as some table rows seemed to have better correspondence than in the OCR version. For the first batch that was run through with Cisdem, the second page with course data was also missing from the file. <br> This is most likely the result of unchanged settings in the program itself, but will have to be double-checked __(Remember!)__
# <br> The certificate in question was "NOR_Tolga_20_16-08_8-3.pdf" (filename remained the same in both folders)

# %% [markdown]
# - __The pdfs made searchable will most likely still need some preprocessing__

# %% [markdown]
#  An example: the pre-table information slots are not read as expected (line-by-line), but rather as two parallell but separate text boxes

# %% [markdown]
# ![Skjermbilde%202021-12-30%20kl.%2012.41.09.png](attachment:Skjermbilde%202021-12-30%20kl.%2012.41.09.png)

# %% [markdown]
# - __The OCR seems to have made the pdfs searchable, but the tabula-py module had trouble running the read_pdf() function__
# <br> Can be seen in codeblocks in "searchable-pdfs.ipynb". Attempted run with both digital+searchable pdf from "NOR-pdfs/" and OCR-result pdf from "searchable-NOR-pdfs/"
