# %% [markdown]
# ## Attempts at getting information from searchable pdfs into tables and DataFrames

# %%
import tabula

# %%
# Read pdf into list of DataFrame
df = tabula.read_pdf("searchable-NOR-pdfs/NOR_Al__Liatoppen_21_20-08_8-3.pdf", pages='all')
# Out:
# Got stderr: des 30, 2021 1:34:56 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider loadDiskCache
# WARNING: New fonts found, font cache will be re-built
# des 30, 2021 1:34:56 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Building on-disk font cache, this may take a while
# des 30, 2021 1:35:00 PM org.apache.pdfbox.pdmodel.font.FileSystemFontProvider <init>
# WARNING: Finished building on-disk font cache, found 784 fonts
# des 30, 2021 1:35:00 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'Helvetica' for 'DefaultMetricsFont'
# des 30, 2021 1:35:00 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'Helvetica-Oblique' for 'DefaultMetricsFont,Italic'
# des 30, 2021 1:35:00 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'Helvetica' for 'DefaultMetricsFont'
# ...

# %%
df = tabula.read_pdf("searchable-NOR-pdfs/NOR_Tolga_20_16-05_3-75.pdf", pages='all')
# Out:
# Got stderr: des 30, 2021 1:37:09 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'Helvetica' for 'DefaultMetricsFont'
# des 30, 2021 1:37:09 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'Helvetica-Oblique' for 'DefaultMetricsFont,Italic'
# des 30, 2021 1:37:09 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# des 30, 2021 1:37:09 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# des 30, 2021 1:37:10 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'Helvetica' for 'DefaultMetricsFont'
# des 30, 2021 1:37:10 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# ...

# %%
#trying out camelot-py through homebrew ++ 
#if wanting to run "brew update" first run "
#git -C /usr/local/Homebrew/Library/Taps/homebrew/homebrew-core fetch --unshallow"

import camelot

# %%
tb = camelot.read_pdf("searchable-NOR-pdfs/NOR_Tolga_20_16-05_3-75.pdf")

# %%
tb[0].parsing_report
# Out:
# {'accuracy': 0, 'whitespace': 100.0, 'order': 1, 'page': 1}

# %%
tb[0].df
# Out:
#   0
# 0
# 1
# 2
# 3

# %% [markdown]
# It seems like the camelot module finds absolutely nothing, which is not ideal

# %% [markdown]
# __Will try to make a new searchable pdf myself and run it with both modules, in hope of seeing them work as we wish__

# %% [markdown]
# ![Skjermbilde%202021-12-30%20kl.%2018.48.52.png](attachment:Skjermbilde%202021-12-30%20kl.%2018.48.52.png)

# %% [markdown]
# This is the table I will try to send in to both camelot and tabula. Still not a fully separated table, in hopes that we will not need something like this. If this does not work either we might have more difficulties than expected in handling the searchable pdfs. PDF to check: "trial-table-searchable.pdf"

# %%
df = tabula.read_pdf("trial-table-searchable.pdf",pages='all')
df
# Out:
# Got stderr: des 30, 2021 7:42:22 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'Helvetica' for 'DefaultMetricsFont'
# des 30, 2021 7:42:22 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# des 30, 2021 7:42:22 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# des 30, 2021 7:42:23 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'Helvetica' for 'DefaultMetricsFont'
# des 30, 2021 7:42:23 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# []

# %%
tb = camelot.read_pdf("trial-table-searchable.pdf")

# %%
tb[0].df
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-713e17cf9712> in <module>
# ----> 1 tb[0].df
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/camelot/core.py in __getitem__(self, idx)
#     687
#     688     def __getitem__(self, idx):
# --> 689         return self._tables[idx]
#     690
#     691     @staticmethod
#
# IndexError: list index out of range

# %% [markdown]
# Does not seem to work either, will have to try in a different way or potentially with other tools

# %%
#Attempt at doing batch conversion with tabula-py

# convert all PDFs in a directory
tabula.convert_into_by_batch("searchable-NOR-pdfs", output_format='csv', pages='all')
# Out:
# Got stderr: des 30, 2021 7:15:58 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'Helvetica' for 'DefaultMetricsFont'
# des 30, 2021 7:15:58 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'Helvetica-Oblique' for 'DefaultMetricsFont,Italic'
# des 30, 2021 7:15:58 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# des 30, 2021 7:15:58 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# des 30, 2021 7:15:59 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'Helvetica' for 'DefaultMetricsFont'
# des 30, 2021 7:15:59 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# ...

# %%
#Attempt at single file conversion to CSV with tabula-py

# convert PDF into CSV file
tabula.convert_into("trial-table-searchable.pdf", "trial-table.csv", output_format="csv", pages='all')
# Out:
# Got stderr: des 30, 2021 7:17:18 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'Helvetica' for 'DefaultMetricsFont'
# des 30, 2021 7:17:19 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# des 30, 2021 7:17:19 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed
# des 30, 2021 7:17:19 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'Helvetica' for 'DefaultMetricsFont'
# des 30, 2021 7:17:19 PM org.apache.pdfbox.contentstream.PDFStreamEngine operatorException
# SEVERE: Cannot read JPEG2000 image: Java Advanced Imaging (JAI) Image I/O Tools are not installed

# %% [markdown]
# ### Tried the Tabula web application, and the developed UI

# %% [markdown]
# ![](screenshot-tabulaUI.PNG)

# %% [markdown]
# We can see that the module here managed to extract the data correctly, meaning that it should be possible to do with tabula-py as well
# <br> To see if we actually managed to extract the data correctly, we try to read a exported csv-file from the tabula app

# %%
file = open("tabula-extracted-csv/tabula-NOR_Tolga_20_16-04_2-5.csv")
file.readlines()
# Out:
# ['"(1) Registration number:",20/16.04/2.5,,\n',
#  '"(2) Name of the competition site:",Tolga,,\n',
#  '"(3) Name of city/region:",Tolga/Hedmark Skikrets,,\n',
#  '"(4) Organizer:",Tolga Idrettslag,,\n',
#  '"(5) National ski association:",Norwegian Ski Federation,,\n',
#  '"(6) Contact person in the organizing committee:",Paul Brennmoen,,\n',
#  '"(7) Homologation inspector:",John Aalberg,,\n',
#  '"(8) Name of course:","2,5 km",,\n',
#  '"(9) Competition level for course",COC,,\n',
#  '"Course length: 2,710m",Height difference (HD): 52m,Lowest point:,557m\n',
#  'Course category: D,Maximum climb (MC): 31m,Highest point:,609m\n',
#  '"",Total climb (TC): 89m,,\n',
#  'Date of Issue\n',
#  '09.04.2020\n',
#  'Valid until\n',
#  '30.06.2025\n']

# %% [markdown]
# Although not super-well in terms of readability, this is a good step in the correct direction. <br> We find the first batch of extracted csv-files in the folder "tabula-extracted-csv/". <br> Have chosen to only extract from a few pdfs (of various readability/styles) because of the time-consuming aspect of the manual processing
